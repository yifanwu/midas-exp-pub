# %% [markdown]
# # Midas Survey
#
# Please conplete the exit survey. You have 15 minutes. The comments are optional. Make sure to run all cells sequentially.

# %%
# Please enter the pid as assigned to you, e.g., "experiment_12"
pid = ...

# %%
from utils import TIME_OPTIONS, LIKELIHOOD, get_comment, get_radio, MidasSurvey, get_options

s = MidasSurvey(pid)

# %% [markdown]
# # Experience with Midas

# %%
q_use = "How do you find the Midas extension overall?"
r_use, a_use = get_radio(q_use, get_options("helpful"))

# %%
s.save_answer(q_use, r_use.value, a_use.value, "use")

# %%
q_future = "Would you use Midas for your future analysis tasks?"
r_future, a_future = get_radio(q_future, LIKELIHOOD)

# %%
s.save_answer(q_future, r_future.value, a_future.value, "future")

# %%
q_learn = "How was it to learn to use Midas?"
r_learn, a_learn = get_radio(q_learn, get_options("easy"))

# %%
s.save_answer(q_learn, r_learn.value, a_learn.value, "learn")

# %% [markdown]
# ## Usage Details

# %%
q = "How did you find the static visualization component?"
r, a = get_radio(q, get_options("helpful"), "The `.vis()` method.")

# %%
s.save_answer(q, r.value, a.value, "static")

# %%
q = "How do you find the interactive visualizations?"
r,a = get_radio(q, get_options("helpful"), "The selections on charts that filters other charts.")

# %%
s.save_answer(q, r.value, a.value, "interactive")

# %%
q = "How do you find the programmatic access to the selections and charts?"
r,a = get_radio(q, get_options("helpul"), "Including the ``.get_code()`, `.get_filtered_data()`, `m.current_selection`, etc.")

# %%
s.save_answer(q, r.value, a.value, "programmatic")

# %%
q = "How do you find the code generated by Midas?"
r,a = get_radio(q, get_options("helpful"), "Consider its applications for providing the context of your analysis so far and providing transparency and reproduceability for others.")

# %%
s.save_answer(q, r.value, a.value, "codegen")

# %%
q = "How do you find context switching between coding and interacting with charts?"
r,a = get_radio(q, get_options("helpful"), "Like writing queries one moment, and then filtering charts another moment.")

# %%
s.save_answer(q, r.value, a.value, "switch")

# %%
q = "Was there any behavior that you were not sure of?"
a = get_comment(q)

# %%
s.save_answer(q, "", a.value, "unsure")

# %%
q = "Anything you think that we can improve on?"
a = get_comment(q)

# %%
s.save_answer(q, "", a.value, "improve")

# %% [markdown]
# # You Day to Day Experience with Data Analysis
#
# We want to get some context about how you work out side of this study.

# %%
q = "How often do you use <i>static</i> visualizations?"
r,a = get_radio(q, TIME_OPTIONS)

# %%
s.save_answer(q, r.value, a.value, "static_before")

# %%
q = "How often do you use <i>interactive</i> visualizations?"
r,a = get_radio(q, TIME_OPTIONS)

# %%
s.save_answer(q, r.value, a.value, "interactive_before")

# %%
q = "Would you consider yourself experienced with data science?"
r,a = get_radio(q, get_options("Experienced"))

# %%
s.save_answer(q, r.value, a.value, "experienced")
