# %% [markdown]
# # Midas Survey
#
# Please conplete the exit survey. You have 15 minutes. The comments are optional. Make sure to run all cells sequentially.

# %%
# Please enter the pid as assigned to you, e.g., "experiment_12"
pid = ...

# %%
from utils import TIME_OPTIONS, LIKELIHOOD, get_comment, get_radio, MidasSurvey, get_options

s = MidasSurvey(pid)

# %% [markdown]
# # Experience with Midas

# %%
q_use = "How do you find the Midas extension overall?"
r_use, a_use = get_radio(q_use, get_options("helpful"))

# %%
s.save_answer(q_use, r_use.value, a_use.value, "use")

# %%
q_future = "Would you use Midas for your future analysis tasks?"
r_future, a_future = get_radio(q_future, LIKELIHOOD)

# %%
s.save_answer(q_future, r_future.value, a_future.value, "future")

# %%
q_learn = "How was it to learn to use Midas?"
r_learn, a_learn = get_radio(q_learn, get_options("easy"))

# %%
s.save_answer(q_learn, r_learn.value, a_learn.value, "learn")

# %% [markdown]
# ## Usage Details

# %%
q_static = "How did you find the static visualization component?"
r_static, a_static = get_radio(q_static, get_options("helpful"), "The `.vis()` method.")

# %%
s.save_answer(q_static, r_static.value, a_static.value, "static")

# %%
q_itx = "How do you find the interactive visualizations?"
r_itx, a_itx = get_radio(q_itx, get_options("helpful"), "The selections on charts that filters other charts.")

# %%
s.save_answer(q_itx, r_itx.value, a_itx.value, "interactive")

# %%
q_programmatic = "How do you find the programmatic access to the selections and charts?"
r_programmatic, a_programmatic = get_radio(q_programmatic, get_options("helpful"), "Including the ``.get_code()`, `.get_filtered_data()`, `m.current_selection`, etc.")

# %%
s.save_answer(q_programmatic, r_programmatic.value, a_programmatic.value, "programmatic")

# %%
q_codegen = "How do you find the code generated by Midas?"
r_codegen, a_codegen = get_radio(q_codegen, get_options("helpful"), "Consider its applications for providing the context of your analysis so far and providing transparency and reproduceability for others.")

# %%
s.save_answer(q_codegen, r_codegen.value, a_codegen.value, "codegen")

# %%
q_switch = "How do you find context switching between coding and interacting with charts?"
r_switch, a_switch = get_radio(q_switch, get_options("straightforward"), "Like writing queries one moment, and then filtering charts another moment.")

# %%
s.save_answer(q_switch, r_switch.value, a_switch.value, "switch")

# %%
q_unsure = "Was there any behavior that you were not sure of?"
a_unsure = get_comment(q_unsure)

# %%
s.save_answer(q_unsure, "", a_unsure.value, "unsure")

# %%
q_improve = "Anything you think that we can improve on?"
a_improve = get_comment(q_improve)

# %%
s.save_answer(q_improve, "", a_improve.value, "improve")

# %% [markdown]
# # You Day to Day Experience with Data Analysis
#
# We want to get some context about how you work out side of this study.

# %%
q_static_before = "How often do you use <i>static</i> visualizations?"
r_static_before, a_static_before = get_radio(q_static_before, TIME_OPTIONS)

# %%
s.save_answer(q_static_before, r_static_before.value, a_static_before.value, "static_before")

# %%
q_interactive_before = "How often do you use <i>interactive</i> visualizations?"
r_interactive_before, a_interactive_before = get_radio(q_interactive_before, TIME_OPTIONS)

# %%
s.save_answer(q_interactive_before, r_interactive_before.value, a_interactive_before.value, "interactive_before")

# %%
q_experienced = "Would you consider yourself experienced with data science?"
r_experienced, a_experienced = get_radio(q_experienced, get_options("Experienced"))

# %%
s.save_answer(q_experienced, r_experienced.value, a_experienced.value, "experienced")
